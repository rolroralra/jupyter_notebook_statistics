# %% [markdown]
# # 다음 문제를 풀이하시오

# %% [markdown]
# ### Q1. Pandas 모듈을 불러오시오.

# %%
import pandas as pd

# %% [markdown]
# ### Q2. "bike.csv"파일을 불러와서 df 객체에 저장하시오.

# %%
df = pd.read_csv("../data/bike.csv")
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# ### Q3. 첫 100개 row만 뽑아서 df100 객체에 저장하시오.

# %%
df100 = df.iloc[:100, :].copy()
df100
# Out:
#                datetime  season  holiday  workingday  weather  temp   atemp  \
# 0   2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1   2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2   2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3   2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4   2011-01-01 04:00:00       1        0           0        1  9.84  14.395
# ..                  ...     ...      ...         ...      ...   ...     ...
# 95  2011-01-05 04:00:00       1        0           1        1  9.84  11.365
# 96  2011-01-05 05:00:00       1        0           1        1  9.02  11.365
# 97  2011-01-05 06:00:00       1        0           1        1  8.20   9.850
# 98  2011-01-05 07:00:00       1        0           1        1  7.38   9.090
# 99  2011-01-05 08:00:00       1        0           1        1  8.20   9.090
#
#     humidity  windspeed  casual  registered  count
# 0         81     0.0000       3          13     16
# 1         80     0.0000       8          32     40
# 2         80     0.0000       5          27     32
# 3         75     0.0000       3          10     13
# 4         75     0.0000       0           1      1
# ..       ...        ...     ...         ...    ...
# 95        48    15.0013       0           2      2
# 96        47    11.0014       0           3      3
# 97        47    15.0013       0          33     33
# 98        43    12.9980       1          87     88
# 99        40    19.9995       3         192    195
#
# [100 rows x 12 columns]

# %% [markdown]
# ### Q4. df100 객체의 row 개수를 출력하시오.

# %%
df100.shape[0]
# Out:
# 100

# %% [markdown]
# ### Q5. df100 객체의 "casual" 변수를 선 그래프로 그려보시오.
# ※ plot() 메서드 사용

# %%
df100["casual"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Q6. df100 객체의 "casual"변수의 12시간 이동평균을 구하여 df100 객체의 "MA_w12" 변수에 집어넣으시오.
# ※ Pandas.Series.rolling(window = number).mean()

# %%
df100["MA_w12"] = df100["casual"].rolling(12).agg("mean")
# df100["MA_w12"] = df100["casual"].rolling(12).mean()

df100
# Out:
#                datetime  season  holiday  workingday  weather  temp   atemp  \
# 0   2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1   2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2   2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3   2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4   2011-01-01 04:00:00       1        0           0        1  9.84  14.395
# ..                  ...     ...      ...         ...      ...   ...     ...
# 95  2011-01-05 04:00:00       1        0           1        1  9.84  11.365
# 96  2011-01-05 05:00:00       1        0           1        1  9.02  11.365
# 97  2011-01-05 06:00:00       1        0           1        1  8.20   9.850
# 98  2011-01-05 07:00:00       1        0           1        1  7.38   9.090
# 99  2011-01-05 08:00:00       1        0           1        1  8.20   9.090
#
#     humidity  windspeed  casual  registered  count    MA_w12
# 0         81     0.0000       3          13     16       NaN
# 1         80     0.0000       8          32     40       NaN
# 2         80     0.0000       5          27     32       NaN
# 3         75     0.0000       3          10     13       NaN
# 4         75     0.0000       0           1      1       NaN
# ..       ...        ...     ...         ...    ...       ...
# 95        48    15.0013       0           2      2  2.833333
# 96        47    11.0014       0           3      3  1.583333
# 97        47    15.0013       0          33     33  0.750000
# 98        43    12.9980       1          87     88  0.583333
# 99        40    19.9995       3         192    195  0.666667
#
# [100 rows x 13 columns]

# %% [markdown]
# ### Q7. "MA_w12" 변수를 선 그래프로 그려보시오.
# ※ plot() 메서드 사용

# %% [markdown]
# ### Q8. "MA_w12" 변수의 결측치는 총 몇 개인가?
